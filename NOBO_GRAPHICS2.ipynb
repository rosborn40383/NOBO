# %%
from prettytable import PrettyTable #Tables look much better!
state_counts = df['STATE'].groupby(df['STATE']).count()
state_counts_sorted = state_counts.sort_values(ascending=False)
table = PrettyTable()
table.field_names = ['STATE', 'COUNT']
for state, count in state_counts_sorted.items():
    table.add_row([state, count])
print(table)
# Out:
# +-------+-------+
# | STATE | COUNT |
# +-------+-------+
# |   KY  |   40  |
# |   FL  |   22  |
# |   NJ  |   18  |
# |   CA  |   13  |
# |   IL  |   12  |
# |   IN  |   10  |
# |   NY  |   9   |
# |   GA  |   9   |
# |   TX  |   9   |
# |   LA  |   9   |
# |   MD  |   8   |
# |   PA  |   8   |
# |   CT  |   7   |
# |   CO  |   6   |
# |   VA  |   6   |
# |   KS  |   6   |
# |   OH  |   5   |
# |   MA  |   5   |
# |   TN  |   4   |
# |   MO  |   4   |
# |   NC  |   4   |
# |   WA  |   4   |
# |   WI  |   4   |
# |   MI  |   3   |
# |   MN  |   3   |
# |   OK  |   2   |
# |   ME  |   2   |
# |   NV  |   2   |
# |   AZ  |   2   |
# |   OR  |   1   |
# |   IA  |   1   |
# |   HI  |   1   |
# |   VT  |   1   |
# |   EX  |   1   |
# |   AL  |   1   |
# +-------+-------+

# %%
from prettytable import PrettyTable
classification_table = prettytable.PrettyTable()
classification_table.field_names = state_classification_sorted.index.tolist()
classification_table.add_row(state_classification_sorted.values.tolist())
print(classification_table)
# Out:
# +--------+-----------------+-----------+-------+-------------------+
# | Retail | Investment Firm | Bond Fund | Other | Insurance Company |
# +--------+-----------------+-----------+-------+-------------------+
# |  114   |        68       |     22    |   21  |         17        |
# +--------+-----------------+-----------+-------+-------------------+

# %%
df['Over_100000_Shares'] = df['SHARES'] > 100000
share_count = df['Over_100000_Shares'].value_counts()
proportion_over_100000 = share_count[1] / len(df) * 100
plt.figure(figsize=(8, 6))
bars = share_count.plot(kind='bar', color='blue')
plt.title('Number of Clients with Over 100,000 Shares')
plt.xlabel('Shares Status')
plt.ylabel('Number of Clients')
for bar in bars.patches:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 0.1, round(yval), ha='center', va='bottom')
plt.text(len(share_count) - 0.25, max(share_count) + 5, f'{round(proportion_over_100000, 2)}% of clients > 100,000', ha='left')
plt.xticks([0, 1], ['Under 100,000 Shares', 'Over 100,000 Shares'], rotation=0)
plt.show()

# %%
df['Over_1000000_Shares'] = df['SHARES'] > 1000000
share_count = df['Over_1000000_Shares'].value_counts()
proportion_over_1000000 = share_count[1] / len(df) * 100
plt.figure(figsize=(8, 6))
bars = share_count.plot(kind='bar', color='blue')
plt.title('Number of Clients with Over 1,000,000 Shares')
plt.xlabel('Shares Status')
plt.ylabel('Number of Clients')
for bar in bars.patches:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 0.1, round(yval), ha='center', va='bottom')
plt.text(len(share_count) - 0.25, max(share_count) + 5, f'{round(proportion_over_1000000, 2)}% of clients > 1,000,000', ha='left')
plt.xticks([0, 1], ['Under 1,000,000 Shares', 'Over 1,000,000 Shares'], rotation=0)
plt.show()

# %%
df['Over_5000000_Shares'] = df['SHARES'] > 5000000
share_count = df['Over_5000000_Shares'].value_counts()
proportion_over_1000000 = share_count[1] / len(df) * 100
plt.figure(figsize=(8, 6))
bars = share_count.plot(kind='bar', color='blue')
plt.title('Number of Clients with Over 5,000,000 Shares')
plt.xlabel('Shares Status')
plt.ylabel('Number of Clients')
for bar in bars.patches:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 0.1, round(yval), ha='center', va='bottom')
plt.text(len(share_count) - 0.25, max(share_count) + 5, f'{round(proportion_over_1000000, 2)}% of clients > 5,000,000', ha='left')
plt.xticks([0, 1], ['Under 5,000,000 Shares', 'Over 5,000,000 Shares'], rotation=0)
plt.show()

# %%
top_shareholders_table = prettytable.PrettyTable()
top_shareholders_table.field_names = top_shareholders_by_cusip.columns.tolist()
for index, row in top_shareholders_by_cusip.iterrows():
    top_shareholders_table.add_row(row.tolist())
print(top_shareholders_table)
# Out:
# +-----------+--------------------------------------+----------+--------------+----------------------------+
# |   CUSIP   |                CLIENT                |  SHARES  | TOTAL SHARES | PROPORTION OF TOTAL SHARES |
# +-----------+--------------------------------------+----------+--------------+----------------------------+
# | 491552S48 | CUMBERLAND CELLULAR LLC              |  300000  |    300000    |           100.0%           |
# | 491552S63 | 28501 FIRST NATIONAL BANKER'S BANK   |  500000  |    750000    |           66.67%           |
# | 491552S71 | BRUCE PARKS                          |  470000  |   1065000    |           44.13%           |
# | 491552S89 | COMMUNITY TRUST AND INVESTMENTS      | 2750000  |   8755000    |           31.41%           |
# | 491552S97 | PHILADELPHIA INS CO                  | 1250000  |   2340000    |           53.42%           |
# | 491552T21 | GLASS LEWIS & CO.  LLC               | 1000000  |   4970000    |           20.12%           |
# | 491552T39 | ISS/13507                            | 4770000  |   5920000    |           80.57%           |
# | 491552T47 | TIB-The Independent BankersBank      | 3995000  |   7110000    |           56.19%           |
# | 491552T54 | 28501 FIRST NATIONAL BANKER'S BANK   | 3000000  |   6345000    |           47.28%           |
# | 491552UY9 | ISS/152/GSAM                         | 2805000  |   12640000   |           22.19%           |
# | 491552UZ6 | NATIONWIDE                           | 11000000 |   41295000   |           26.64%           |
# +-----------+--------------------------------------+----------+--------------+----------------------------+

# %%
import prettytable #missing CUSIP % is how much data is missing from total shares
missing_cusip_table = prettytable.PrettyTable()
missing_cusip_table.field_names = missing_cusip_df.columns.tolist()
for _, row in missing_cusip_df.iterrows():
    missing_cusip_table.add_row(row.tolist())
print(missing_cusip_table)
# Out:
# +-----------+---------------+---------------------+-----------------+
# |   CUSIP   | MATURITY YEAR | TOTAL SHARES ISSUED | MISSING CUSIP % |
# +-----------+---------------+---------------------+-----------------+
# | 491552S48 |      2024     |       1040000       |      71.15%     |
# | 491552S63 |      2026     |       1055000       |      28.91%     |
# | 491552S71 |      2027     |       1065000       |       0.0%      |
# | 491552S89 |      2028     |       12560000      |      30.29%     |
# | 491552S97 |      2029     |       12765000      |      81.67%     |
# | 491552T21 |      2030     |       12990000      |      61.74%     |
# | 491552T39 |      2031     |       13235000      |      55.27%     |
# | 491552T47 |      2032     |       13495000      |      47.31%     |
# | 491552T54 |      2033     |       13785000      |      53.97%     |
# | 491552UY9 |      2025     |       91015000      |      86.11%     |
# | 491552UZ6 |      2030     |       96625000      |      57.26%     |
# +-----------+---------------+---------------------+-----------------+

# %%
print(table)
# Out:
# +------------------------------------------+--------------------------------------+------------+--------------------+
# |                  CUSIP                   |                CLIENT                | PROPORTION | PROPORTION OVERALL |
# +------------------------------------------+--------------------------------------+------------+--------------------+
# |                491552S48                 | CUMBERLAND CELLULAR LLC              |   100.0    |        29%         |
# | ---------------------------------------- |                                      |            |                    |
# |                491552S63                 | 28501 FIRST NATIONAL BANKER'S BANK   |   66.67    |        47%         |
# |                491552S63                 | CITY OF BOWLING GREEN GENERAL        |   33.33    |        24%         |
# | ---------------------------------------- |                                      |            |                    |
# |                491552S71                 | BRUCE PARKS                          |   44.13    |        44%         |
# |                491552S71                 | CITY OF BOWLING GREEN GENERAL        |    27.7    |        28%         |
# |                491552S71                 | MOLINA HEALTHCARE OF WASHINGTON  INC |   23.47    |        23%         |
# | ---------------------------------------- |                                      |            |                    |
# |                491552S89                 | COMMUNITY TRUST AND INVESTMENTS      |   31.41    |        22%         |
# |                491552S89                 | 28501 FIRST NATIONAL BANKER'S BANK   |   22.84    |        16%         |
# |                491552S89                 | 151 E. St Paul Ave                   |   11.42    |         8%         |
# | ---------------------------------------- |                                      |            |                    |
# |                491552S97                 | PHILADELPHIA INS CO                  |   53.42    |        10%         |
# |                491552S97                 | AIG                                  |   25.64    |         5%         |
# | ---------------------------------------- |                                      |            |                    |
# |                491552T21                 | GLASS LEWIS & CO.  LLC               |   20.12    |         8%         |
# |                491552T21                 | SOUTHWEST MARINE AND GENERAL INSURAN |   12.07    |         5%         |
# |                491552T21                 | HOMETOWN BANK                        |   10.06    |         4%         |
# |                491552T21                 | 28501 FIRST NATIONAL BANKER'S BANK   |   10.06    |         4%         |
# | ---------------------------------------- |                                      |            |                    |
# |                491552T39                 | ISS/13507                            |   80.57    |        36%         |
# | ---------------------------------------- |                                      |            |                    |
# |                491552T47                 | TIB-The Independent BankersBank      |   56.19    |        30%         |
# |                491552T47                 | 28501 FIRST NATIONAL BANKER'S BANK   |   17.58    |         9%         |
# | ---------------------------------------- |                                      |            |                    |
# |                491552T54                 | 28501 FIRST NATIONAL BANKER'S BANK   |   47.28    |        22%         |
# |                491552T54                 | TIB-The Independent BankersBank      |   47.28    |        22%         |
# | ---------------------------------------- |                                      |            |                    |
# |                491552UY9                 | ISS/152/GSAM                         |   22.19    |         3%         |
# |                491552UY9                 | XL RE EUROPE SE                      |   20.69    |         3%         |
# |                491552UY9                 | 702 KING FARM BLVD                   |   11.83    |         2%         |
# |                491552UY9                 | PROXY FOR AT 93                      |   11.83    |         2%         |
# | ---------------------------------------- |                                      |            |                    |
# |                491552UZ6                 | NATIONWIDE                           |   26.64    |        11%         |
# |                491552UZ6                 | UNUM PROVIDENT CORP                  |   16.95    |         7%         |
# | ---------------------------------------- |                                      |            |                    |
# +------------------------------------------+--------------------------------------+------------+--------------------+
